# %%
#import libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
#Connect to website and pull in data

URL = 'https://www.amazon.in/Starton-Apparel-T-Shirt-Supercar-Oversized/dp/B0F92PW1WJ/ref=sr_1_1?crid=3PIBVEC6K2GMR&dib=eyJ2IjoiMSJ9.9u6gqFdRMKdqWBZQWmsueiQNS9i1MiUar9YKwQ1qFuQTSHRn0EhoD6ZtAL3CdbYXTEgUMeUnxIpkjRvtsccVdQSODngKafC9vJxcWFh6YI2v-yY8TO-4_H8H0yOF1uAt0IquzvquQ87BcqRkDXHirnaviONulL5vztbwb2N7JHjyZP79KLl3z1njXHmW5LjDeYWVeTUMLrJd0pRSpnG4vXob2iEEyJk4ZIyr28-97-kfEJhvWukBJrHE5vROcD2lhVd4pg46syw24jieKKM_lvqKjRekC3kpXhkSlRDpwGs.y_t9IHxhbc2Glgp_QXb6jVLYueInUlPjBlQWI9heGWY&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1772301866&sprefix=data%2Banalyst%2Caps%2C350&sr=8-1&th=1&psc=1'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36", 
    "X-Amzn-Trace-Id": "Root=1-69a32e70-239ae5a631e49963412305ee"}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, 'html.parser')

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id = 'productTitle').get_text()

price = soup2.find(class_="a-price-whole").get_text()

print(title)

print(price)
# Out:
#                  Unisex Cotton T-Shirt from ula 1 Supercar Graphic Print Oversized Fit
#
#
#                    469

# %%
# Clean up the data a little bit

price = price.strip()
title = title.strip()

print(title)
print(price)
# Out:
# Unisex Cotton T-Shirt from ula 1 Supercar Graphic Print Oversized Fit
# 469

# %%
type(price)
# Out:
# str

# %%
# Create a Timestamp for your output to track when data was collected

import datetime

today = datetime.date.today()

print(today)
# Out:
# 2026-03-02

# %%
# Create csv and write headers and data into the file

import csv

header = ['Title', 'Price', 'Date']

data = [title, price, today]

with open('AmazonWebScraperDataset.csv', 'w', newline = '', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Python Series\AmazonWebScraperDataset.csv")

# %%
print(df)
# Out:
#                                                Title  Price        Date
# 0  Unisex Cotton T-Shirt from ula 1 Supercar Grap...    469  2026-03-02

# %%
#Now we are appending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#Combine all of the above code into one funtion

def check_price():
    URL = 'https://www.amazon.in/Starton-Apparel-T-Shirt-Supercar-Oversized/dp/B0F92PW1WJ/ref=sr_1_1?crid=3PIBVEC6K2GMR&dib=eyJ2IjoiMSJ9.9u6gqFdRMKdqWBZQWmsueiQNS9i1MiUar9YKwQ1qFuQTSHRn0EhoD6ZtAL3CdbYXTEgUMeUnxIpkjRvtsccVdQSODngKafC9vJxcWFh6YI2v-yY8TO-4_H8H0yOF1uAt0IquzvquQ87BcqRkDXHirnaviONulL5vztbwb2N7JHjyZP79KLl3z1njXHmW5LjDeYWVeTUMLrJd0pRSpnG4vXob2iEEyJk4ZIyr28-97-kfEJhvWukBJrHE5vROcD2lhVd4pg46syw24jieKKM_lvqKjRekC3kpXhkSlRDpwGs.y_t9IHxhbc2Glgp_QXb6jVLYueInUlPjBlQWI9heGWY&dib_tag=se&keywords=data%2Banalyst%2Btshirt&qid=1772301866&sprefix=data%2Banalyst%2Caps%2C350&sr=8-1&th=1&psc=1'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36", 
    "X-Amzn-Trace-Id": "Root=1-69a32e70-239ae5a631e49963412305ee"}

    page = requests.get(URL, headers=headers)

    soup1 = BeautifulSoup(page.content, 'html.parser')

    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id = 'productTitle').get_text()

    price = soup2.find(class_="a-price-whole").get_text()

    price = price.strip()
    title = title.strip()

    import datetime

    today = datetime.date.today()

    import csv

    header = ['Title', 'Price', 'Date']

    data = [title, price, today]

    with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding = 'UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

    if(price < 400):
        send_mail()

# %%
#Runs check_price after a set time and inputs data into your CSV

import time

while(True):
    check_price()
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 6
#       3 import time
#       5 while(True):
# ----> 6     check_price()
#       7     time.sleep(5)
#
# Cell In[27], line 13, in check_price()
#       9 page = requests.get(URL, headers=headers)
#      11 soup1 = BeautifulSoup(page.content, 'html.parser')
# ---> 13 soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
#      15 title = soup2.find(id = 'productTitle').get_text()
#      17 price = soup2.find(class_="a-price-whole").get_text()
#
# File ~\anaconda3\Lib\site-packages\bs4\__init__.py:476, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     474 self.builder.initialize_soup(self)
#     475 try:
# --> 476     self._feed()
#     477     success = True
#     478     break
#
# ...

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Python Series\AmazonWebScraperDataset.csv")
print(df)
# Out:
#                                                Title  Price        Date
# 0  Unisex Cotton T-Shirt from ula 1 Supercar Grap...    469  2026-03-02

# %%
#If you want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('mahajanadeena@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want is below 400! Now is your chance to buy!"
    body = "Adeena, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'mahajanadeena@gmail.com',
        msg
    )
    server.quit()
